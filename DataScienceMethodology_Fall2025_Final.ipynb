# %% [markdown]
# ## 1. Data Collection

# %% [markdown]
# ### 1.1 Method
# - Source(s) : [rapid api](https://rapidapi.com/)
# - Tools used (requests)

# %% [markdown]
# ### 1.2 Raw data set

# %%
import pandas as pd
df = pd.read_csv("houston_rentals.csv")
df.head()
# Out:
#    beds  baths    sqft  property_type  year_built  list_price  \
# 0   3.0    2.0  1424.0  single_family      1960.0       950.0
# 1   4.0    3.5  4036.0  single_family      1977.0      1600.0
# 2   1.0    1.0   624.0   multi_family      1929.0      1075.0
# 3   2.0    1.5  1115.0      townhomes      1978.0      1495.0
# 4   2.0    2.0  1147.0         condos      2010.0      2083.0
#
#                      list_date  listing_id    status  property_id  ...  \
# 0  2025-10-29T00:08:28.000000Z  2987806759  for_rent   8136465641  ...
# 1  2025-11-21T21:19:20.000000Z  2988913356  for_rent   8242065860  ...
# 2  2025-10-24T17:02:48.000000Z  2987679426  for_rent   9527760316  ...
# 3  2025-10-21T21:07:19.000000Z  2987572173  for_rent   7119355113  ...
# 4  2025-11-30T23:33:42.000000Z  2989081843  for_rent   7750671973  ...
#
#                            detail_school_information  \
# 0                                                NaN
# 1                                                NaN
# 2  Elementary School: BURNET ELEMENTARY SCHOOL (H...
# 3  Elementary School: WALNUT BEND ELEMENTARY SCHO...
# 4  Elementary School: GREGORY-LINCOLN ELEMENTARY ...
#
#              detail_amenities_and_community_features  \
# 0                                                NaN
# 1                                                NaN
# 2                          Community Features: Curbs
# 3                                                NaN
# 4  Community Features: CommunityPool, Clubhouse, ...
#
#                                     detail_utilities  \
# 0                                                NaN
# 1                                                NaN
# 2  Sewer: PublicSewer | NaturalGasAvailable | Sew...
# 3          Sewer: PublicSewer | Water Source: Public
# 4  Sewer: PublicSewer | CableAvailable | Water So...
#
#                            detail_kitchen_and_dining  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Dining Room Dimensions: 12' x 9' | Dining Room...
# 4  Dining Room Dimensions: 9'10" x 11'9" | Dining...
#
#                            detail_pool_and_spa  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4  Pool Features: InGround | Pool Private: Yes
#
#                                 detail_home_features  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Security Features: SecurityGate, KeyCardEntry,...
#
#    detail_community_features detail_multi-unit_info  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
#
#    detail_listing_information detail_accessibility_features
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
# [5 rows x 44 columns]

# %% [markdown]
# ## 2. Dataset Overview and Inspection

# %% [markdown]
# ### <center style="color:#007ACC;">===== BASIC OVERVIEW =====</center>

# %%
print("Shape:", df.shape)
print("="*40)
print("Info:")
print("="*40)
print(df.info())
# Out:
# Shape: (2800, 44)
# ========================================
# Info:
# ========================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 44 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   beds                                     2772 non-null   float64
#  1   baths                                    2758 non-null   float64
#  2   sqft                                     2744 non-null   float64
#  3   property_type                            2800 non-null   object
#  4   year_built                               2615 non-null   float64
#  5   list_price                               2772 non-null   float64
#  6   list_date                                2766 non-null   object
#  7   listing_id                               2800 non-null   int64
#  8   status                                   2800 non-null   object
#  9   property_id                              2800 non-null   int64
#  10  address_line                             2800 non-null   object
#  11  city                                     2800 non-null   object
#  12  state                                    2800 non-null   object
#  13  postal_code                              2800 non-null   int64
#  14  country                                  2800 non-null   object
#  15  latitude                                 2761 non-null   float64
#  16  longitude                                2761 non-null   float64
#  17  county_name                              2800 non-null   object
#  18  county_fips                              2761 non-null   float64
#  19  detail_bedrooms                          2772 non-null   object
#  20  detail_interior_features                 1189 non-null   object
#  21  detail_heating_and_cooling               2226 non-null   object
#  22  detail_bathrooms                         2758 non-null   object
#  23  detail_rental_info                       2685 non-null   object
#  24  detail_other_property_info               2772 non-null   object
#  25  detail_building_and_construction         2758 non-null   object
#  26  other_listings_count                     2800 non-null   int64
#  27  listing_history                          2800 non-null   object
#  28  detail_exterior_and_lot_features         854 non-null    object
#  29  detail_homeowners_association            2484 non-null   object
#  30  detail_other_rooms                       2587 non-null   object
#  31  detail_appliances                        1137 non-null   object
#  32  detail_land_info                         1789 non-null   object
#  33  detail_garage_and_parking                1265 non-null   object
#  34  detail_school_information                2545 non-null   object
#  35  detail_amenities_and_community_features  1951 non-null   object
#  36  detail_utilities                         2083 non-null   object
#  37  detail_kitchen_and_dining                678 non-null    object
#  38  detail_pool_and_spa                      285 non-null    object
#  39  detail_home_features                     653 non-null    object
#  40  detail_community_features                28 non-null     object
#  41  detail_multi-unit_info                   123 non-null    object
#  42  detail_listing_information               28 non-null     object
#  43  detail_accessibility_features            28 non-null     object
# dtypes: float64(8), int64(4), object(32)
# memory usage: 962.6+ KB
# None

# %% [markdown]
# ### <center style="color:#007ACC;">===== DUPLICATES CHECK =====</center>

# %% [markdown]
# ## 3. Data Cleaning

# %%
df.head()
# Out:
#    beds  baths    sqft  property_type  year_built  list_price  \
# 0   3.0    2.0  1424.0  single_family      1960.0       950.0
# 1   4.0    3.5  4036.0  single_family      1977.0      1600.0
# 2   1.0    1.0   624.0   multi_family      1929.0      1075.0
# 3   2.0    1.5  1115.0      townhomes      1978.0      1495.0
# 4   2.0    2.0  1147.0         condos      2010.0      2083.0
#
#                      list_date  listing_id    status  property_id  ...  \
# 0  2025-10-29T00:08:28.000000Z  2987806759  for_rent   8136465641  ...
# 1  2025-11-21T21:19:20.000000Z  2988913356  for_rent   8242065860  ...
# 2  2025-10-24T17:02:48.000000Z  2987679426  for_rent   9527760316  ...
# 3  2025-10-21T21:07:19.000000Z  2987572173  for_rent   7119355113  ...
# 4  2025-11-30T23:33:42.000000Z  2989081843  for_rent   7750671973  ...
#
#                            detail_school_information  \
# 0                                                NaN
# 1                                                NaN
# 2  Elementary School: BURNET ELEMENTARY SCHOOL (H...
# 3  Elementary School: WALNUT BEND ELEMENTARY SCHO...
# 4  Elementary School: GREGORY-LINCOLN ELEMENTARY ...
#
#              detail_amenities_and_community_features  \
# 0                                                NaN
# 1                                                NaN
# 2                          Community Features: Curbs
# 3                                                NaN
# 4  Community Features: CommunityPool, Clubhouse, ...
#
#                                     detail_utilities  \
# 0                                                NaN
# 1                                                NaN
# 2  Sewer: PublicSewer | NaturalGasAvailable | Sew...
# 3          Sewer: PublicSewer | Water Source: Public
# 4  Sewer: PublicSewer | CableAvailable | Water So...
#
#                            detail_kitchen_and_dining  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Dining Room Dimensions: 12' x 9' | Dining Room...
# 4  Dining Room Dimensions: 9'10" x 11'9" | Dining...
#
#                            detail_pool_and_spa  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4  Pool Features: InGround | Pool Private: Yes
#
#                                 detail_home_features  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Security Features: SecurityGate, KeyCardEntry,...
#
#    detail_community_features detail_multi-unit_info  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
#
#    detail_listing_information detail_accessibility_features
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
# [5 rows x 44 columns]

# %% [markdown]
# ### 3.1 Droping Unnecessary Columns

# %%
df_cleaned = df.drop(columns=['status','city','state','postal_code','country','county_name','county_fips','listing_history'])
df_cleaned.head()
# Out:
#    beds  baths    sqft  property_type  year_built  list_price  \
# 0   3.0    2.0  1424.0  single_family      1960.0       950.0
# 1   4.0    3.5  4036.0  single_family      1977.0      1600.0
# 2   1.0    1.0   624.0   multi_family      1929.0      1075.0
# 3   2.0    1.5  1115.0      townhomes      1978.0      1495.0
# 4   2.0    2.0  1147.0         condos      2010.0      2083.0
#
#                      list_date  listing_id  property_id  \
# 0  2025-10-29T00:08:28.000000Z  2987806759   8136465641
# 1  2025-11-21T21:19:20.000000Z  2988913356   8242065860
# 2  2025-10-24T17:02:48.000000Z  2987679426   9527760316
# 3  2025-10-21T21:07:19.000000Z  2987572173   7119355113
# 4  2025-11-30T23:33:42.000000Z  2989081843   7750671973
#
#                 address_line  ...  \
# 0          5815 Effingham Dr  ...
# 1        18103 Ravenfield Dr  ...
# 2              4603 Canal St  ...
# 3  10814 Sugar Hill Dr Apt B  ...
# 4    306 McGowen St Apt 1219  ...
#
#                            detail_school_information  \
# 0                                                NaN
# 1                                                NaN
# 2  Elementary School: BURNET ELEMENTARY SCHOOL (H...
# 3  Elementary School: WALNUT BEND ELEMENTARY SCHO...
# 4  Elementary School: GREGORY-LINCOLN ELEMENTARY ...
#
#              detail_amenities_and_community_features  \
# 0                                                NaN
# 1                                                NaN
# 2                          Community Features: Curbs
# 3                                                NaN
# 4  Community Features: CommunityPool, Clubhouse, ...
#
#                                     detail_utilities  \
# 0                                                NaN
# 1                                                NaN
# 2  Sewer: PublicSewer | NaturalGasAvailable | Sew...
# 3          Sewer: PublicSewer | Water Source: Public
# 4  Sewer: PublicSewer | CableAvailable | Water So...
#
#                            detail_kitchen_and_dining  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Dining Room Dimensions: 12' x 9' | Dining Room...
# 4  Dining Room Dimensions: 9'10" x 11'9" | Dining...
#
#                            detail_pool_and_spa  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4  Pool Features: InGround | Pool Private: Yes
#
#                                 detail_home_features  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Security Features: SecurityGate, KeyCardEntry,...
#
#   detail_community_features detail_multi-unit_info detail_listing_information  \
# 0                       NaN                    NaN                        NaN
# 1                       NaN                    NaN                        NaN
# 2                       NaN                    NaN                        NaN
# 3                       NaN                    NaN                        NaN
# 4                       NaN                    NaN                        NaN
#
#    detail_accessibility_features
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# ### 3.1 Handling Missing Values

# %% [markdown]
# ### 3.2 Removing Duplicates

# %% [markdown]
# ### 3.3 Correcting Formats

# %% [markdown]
# ### 3.4 Treating Outliers

# %% [markdown]
# ## 4. Exploratory Data Analysis (EDA)
